# %% [markdown]
# # CFIS / eBOSS / BOSS common areas

# %%
# %matplotlib inline

# %%
# %run ~/ShapePipe/scripts/python/cfis_field_select.py -i ~/astro/data/CFIS/tiles/ls_20171206.txt \
    -b r -t tiles -v -m a --area 110deg_40deg_260deg_60deg -o area_eBOSS_QSO_NGC --plot --interactive
# Out:
# /Users/mkilbing/ShapePipe/scripts/python/cfis_field_select.py -i /Users/mkilbing/astro/data/CFIS/tiles/ls_20171206.txt -b r -t tiles -v -m a --area 110deg_40deg_260deg_60deg -o area_eBOSS_QSO_NGC --plot --interactive
# Start program cfis_field_select.py
# 3447 image files found in input file '/Users/mkilbing/astro/data/CFIS/tiles/ls_20171206.txt'
# Looking for all images within coordinates  [<SkyCoord (ICRS): (ra, dec) in deg
#     ( 110.,  40.)>, <SkyCoord (ICRS): (ra, dec) in deg
#     ( 260.,  60.)>]
# 958 images found in area
# Creating plots
# Saving plot to area_eBOSS_QSO_NGC.pdf
# Finish program cfis_field_select.py

# %%
# %run ~/ShapePipe/scripts/python/cfis_field_select.py -i ~/astro/data/CFIS/tiles/ls_20171206.txt \
    -b r -t tiles -v -m a --area 130deg_22deg_170deg_34deg -o area_eBOSS25 --plot --interactive
# Out:
# /Users/mkilbing/ShapePipe/scripts/python/cfis_field_select.py -i /Users/mkilbing/astro/data/CFIS/tiles/ls_20171206.txt -b r -t tiles -v -m a --area 130deg_22deg_170deg_34deg -o area_eBOSS25 --plot --interactive
# Start program cfis_field_select.py
# 3447 image files found in input file '/Users/mkilbing/astro/data/CFIS/tiles/ls_20171206.txt'
# Looking for all images within coordinates  [<SkyCoord (ICRS): (ra, dec) in deg
#     ( 130.,  22.)>, <SkyCoord (ICRS): (ra, dec) in deg
#     ( 170.,  34.)>]
# 185 images found in area
# Creating plots
# Saving plot to area_eBOSS25.pdf
# /Users/mkilbing/anaconda3/lib/python3.6/site-packages/matplotlib/figure.py:1999: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   warnings.warn("This figure includes Axes that are not compatible "
# Finish program cfis_field_select.py
